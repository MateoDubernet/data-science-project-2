# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Partie A - Nettoyage des données

# %% [markdown]
# ## Question 1 :  Cleaning variable availability
#
# La variable availability contient des chaînes de caractères. Transformer ces valeurs en des valeurs de type datetime en faisant l'hypothèse que nous sommes le 01/01/2023 (ie pour les occurences 'Immediate Possession' et 'Ready To Move') et que l'année de toutes les dates est 2023. On remplacera les valeurs de la colonne availability par ces valeurs.

# %%
df = pd.read_csv("../data/dataset.csv")

df.loc[df['availability'] == 'Immediate Possession', 'availability'] = '01-Jan'
df.loc[df['availability'] == 'Ready To Move', 'availability'] = '01-Jan'
df['availability'] = pd.to_datetime(df['availability'], format='%d-%b')
df['availability'] = df['availability'] +  pd.DateOffset(years=123)

df
# Out:
#                   area_type availability                  location       size  \
# 0      Super built-up  Area   2023-12-19  Electronic City Phase II      2 BHK
# 1                Plot  Area   2023-01-01          Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area   2023-01-01               Uttarahalli      3 BHK
# 3      Super built-up  Area   2023-01-01        Lingadheeranahalli      3 BHK
# 4      Super built-up  Area   2023-01-01                  Kothanur      2 BHK
# ...                     ...          ...                       ...        ...
# 13315        Built-up  Area   2023-01-01                Whitefield  5 Bedroom
# 13316  Super built-up  Area   2023-01-01             Richards Town      4 BHK
# 13317        Built-up  Area   2023-01-01     Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area   2023-06-18           Padmanabhanagar      4 BHK
# 13319  Super built-up  Area   2023-01-01              Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony   price
# 0      Coomee        1056   2.0      1.0   39.07
# 1      Theanmp       2600   5.0      3.0  120.00
# 2          NaN       1440   2.0      3.0   62.00
# 3      Soiewre       1521   3.0      1.0   95.00
# 4          NaN       1200   2.0      1.0   51.00
# ...        ...        ...   ...      ...     ...
# 13315  ArsiaEx       3453   4.0      0.0  231.00
# 13316      NaN       3600   5.0      NaN  400.00
# 13317  Mahla T       1141   2.0      1.0   60.00
# 13318  SollyCl       4689   4.0      1.0  488.00
# 13319      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %% [markdown]
# ## Question 2:  Cleaning variable size
#
# La variable size contient des chaînes de caractères. Regarder des valeurs et comprendre ce qu'elles veulent dire (on pourra en chercher quelques une sur internet), afin de transformer ces valeurs en des valeurs d'un type numérique (attention il y a des valeurs manquantes). On remplacera les valeurs de la colonne size par ces valeurs.

# %%
df['size'] = df['size'].replace(to_replace ='[A-Za-z]', value ='', regex = True)
df['size'] = df['size'].fillna(np.NaN)
df.loc[pd.notnull(df['size']), 'size'] = df.loc[pd.notnull(df['size']), 'size'].astype(float)

# Si je rajoute pas cette ligne, j'obtient un dtype = Object
# au lieu d'un dtype = float64 comme indiqué dans la partie Vérification
df['size'] = pd.to_numeric(df['size'], errors='coerce') 

df
# Out:
# 0        2.0
# 1        4.0
# 2        3.0
# 3        3.0
# 4        2.0
#         ...
# 13315    5.0
# 13316    4.0
# 13317    2.0
# 13318    4.0
# 13319    1.0
# Name: size, Length: 13320, dtype: float64

# %% [markdown]
# ## Question 3 :  Cleaning de la variable total_sqft
#
# La variable total_sqft est la surface du bien immobilier mais est encodé en tant que string. Convertir cette valeur en une valeur d'un type numérique. On remplacera les valeurs de la colonne total_sqft par ces valeurs (il n'y a pas besoin de gérer tous les cas, on peut se contenter de 80 / 90 % des lignes qui auront une valeur non nulle renseignée et renvoyer np.nan pour les autre 10 / 20 % cas).

# %%
# Supprimer tous les caractères qui ne sont pas des chiffres ou des points décimaux
# df['total_sqft'] = df['total_sqft'].str.replace('[^0-9.]', '',  regex=True) 

# Ne conserve que la partie de la chaîne qui correspond au motif à l'intérieur des parenthèses,
# Le premier point décimal de la chaîne s'il est précédé d'au moins un chiffre et suivi d'un chiffre au moins
# df['total_sqft'] = df['total_sqft'].str.replace(r'^(\d+\.\d+)\..*', r'\1', regex=True)

# df['total_sqft'] = df['total_sqft'].apply(lambda x: float(x.split(' ')[0]))
# df['total_sqft'] = df['total_sqft'].fillna(np.NaN)
# df.loc[pd.notnull(df['total_sqft']), 'total_sqft'] = df.loc[pd.notnull(df['total_sqft']), 'total_sqft'].astype(float)

# %%
def clean_total_sqft(value):
    # Supprimer tous les caractères non numériques et pas un "."
    value = ''.join(c for c in value if c.isdigit() or c == '.' or c == ' ')

    # Diviser la chaîne en parties en fonction des espaces
    parts = value.split()

    # Si la chaîne est composée de deux parties, calculer la moyenne de l'intervalle
    if len(parts) == 2:
        return (float(parts[0]) + float(parts[1])) / 2
    # Si la chaîne n'a qu'une partie, elle est retournée sous forme de flottant.
    elif len(parts) == 1:
        # Supprimer les points qui trainent après traitement
        value = parts[0].rstrip('.')
        return float(value)
    # Si la chaîne est vide ou comporte plus de deux parties, elle renvoie NaN.
    else:
        return np.NaN

# Appliquer la fonction de nettoyage à la colonne "total_sqft".
df['total_sqft'] = df['total_sqft'].apply(clean_total_sqft)
df['total_sqft'] = df['total_sqft'].astype('float64')
df
# Out:
#                   area_type availability                  location  size  \
# 0      Super built-up  Area   2023-12-19  Electronic City Phase II   2.0
# 1                Plot  Area   2023-01-01          Chikka Tirupathi   4.0
# 2            Built-up  Area   2023-01-01               Uttarahalli   3.0
# 3      Super built-up  Area   2023-01-01        Lingadheeranahalli   3.0
# 4      Super built-up  Area   2023-01-01                  Kothanur   2.0
# ...                     ...          ...                       ...   ...
# 13315        Built-up  Area   2023-01-01                Whitefield   5.0
# 13316  Super built-up  Area   2023-01-01             Richards Town   4.0
# 13317        Built-up  Area   2023-01-01     Raja Rajeshwari Nagar   2.0
# 13318  Super built-up  Area   2023-06-18           Padmanabhanagar   4.0
# 13319  Super built-up  Area   2023-01-01              Doddathoguru   1.0
#
#        society  total_sqft  bath  balcony   price
# 0      Coomee       1056.0   2.0      1.0   39.07
# 1      Theanmp      2600.0   5.0      3.0  120.00
# 2          NaN      1440.0   2.0      3.0   62.00
# 3      Soiewre      1521.0   3.0      1.0   95.00
# 4          NaN      1200.0   2.0      1.0   51.00
# ...        ...         ...   ...      ...     ...
# 13315  ArsiaEx      3453.0   4.0      0.0  231.00
# 13316      NaN      3600.0   5.0      NaN  400.00
# 13317  Mahla T      1141.0   2.0      1.0   60.00
# 13318  SollyCl      4689.0   4.0      1.0  488.00
# 13319      NaN       550.0   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %% [markdown]
# ## Question 4 :  Vérification
#
#
# Après toutes ces étapes, la méthode `.info()` appliquée sur la DataFrame `df` doit afficher l'output suivant (où les XXXXX sont des valeurs qui dépendent de vos traitements):
#
# |   |              |                |                |
# |--:|--------------|----------------|----------------|
# | 0 | area_type    | 13320 non-null | object         |
# | 1 | availability | 13320 non-null | datetime64[ns] |
# | 2 | location     | 13319 non-null | object         |
# | 3 | size         | XXXXX non-null | float64        |
# | 4 | society      | 7818 non-null  | object         |
# | 5 | total_sqft   | XXXXX non-null | float64        |
# | 6 | bath         | 13247 non-null | float64        |
# | 7 | balcony      | 12711 non-null | float64        |
# | 8 | price        | 13320 non-null | float64        |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  datetime64[ns]
#  2   location      13319 non-null  object
#  3   size          13304 non-null  float64
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  float64
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 936.7+ KB

# %% [markdown]
# ## Question 5 : Sauvegarde et Amélioration cleaning
#
# Sauvegarder cette dataframe dans une table SQL stockée sur Scalingo nommée data_cleaned (avec les nouvelles valeurs availability, size et total_sqft)
#
# Veiller à ce que le cleaning de la variable total_sqft permette de renseigner plus de 99% des valeurs.
#
# Sauvegarder cette dataframe dans une table SQL stockée sur Scalingo nommée data_cleaned_2

# %%
from sqlalchemy import create_engine
DATABASE_URL = "postgresql+psycopg2://data_scienc_6492:EKm5CscefPfDiUmxIOUV@data-scienc-6492.postgresql.a.osc-fr1.scalingo-dbs.com:32678/data_scienc_6492?sslmode=prefer"
engine = create_engine(DATABASE_URL, connect_args={'sslmode': "allow"})

# Dans notre cas, on a déjà 99% des valeurs de total_sqft renseignées

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
#
# df.to_sql('data_cleaned', engine)

# %% [markdown]
# # Partie B - Statistiques Descriptives

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Question 1 : Scatter plots
#
# Pour chaque variable quantitative autre que le prix, la représenter dans un scatter plot en abscisse, avec en ordonnée le prix.

# %%
plt.plot(df['size'], df['price'], 'o')
plt.xlabel('size')
plt.ylabel('price')
plt.show()

# %%
plt.plot(df['total_sqft'], df['price'], 'o') 
plt.xlabel('surface')
plt.ylabel('price')
plt.show()

# %%
plt.plot(df['bath'], df['price'], 'o') 
plt.xlabel('Bathroom')
plt.ylabel('price')
plt.show()

# %%
plt.plot(df['balcony'], df['price'], 'o') 
plt.xlabel('Balcony')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ## Question 2 :
#
# Représenter un graphique qui permet de déterminer pour quel nombre de balcons les biens ont le prix moyen le plus élevé.

# %%
mean_price_by_number_of_balcony = df.groupby('balcony')['price'].mean()
mean_price_by_number_of_balcony
# Out:
# balcony
# 0.0    110.698469
# 1.0     85.730063
# 2.0    109.981948
# 3.0    150.748768
# Name: price, dtype: float64

# %%
plt.hist(mean_price_by_number_of_balcony.index, weights=mean_price_by_number_of_balcony.values, bins=range(0,6), alpha=0.5)
plt.xlabel('Nombre de balcons')
plt.ylabel('Prix moyen')
plt.show()

# %% [markdown]
# **Commentaire** : On voit bien que le prix moyen est le plus élevé lorsque le nombre de balcons est égal à **3**.

# %% [markdown]
# ## Question 3 :
# Faire de même avec les salles de bains à la place des balcons.

# %%
mean_price_by_number_of_bathrooms = df.groupby('bath')['price'].mean()
mean_price_by_number_of_bathrooms
# Out:
# bath
# 1.0       47.584632
# 2.0       63.404087
# 3.0      125.131888
# 4.0      237.005812
# 5.0      309.363073
# 6.0      283.223443
# 7.0      300.352941
# 8.0      268.640625
# 9.0      281.069767
# 10.0     217.307692
# 11.0     188.333333
# 12.0     291.428571
# 13.0    1341.666667
# 14.0     500.000000
# 15.0     125.000000
# 16.0     520.000000
# 18.0     200.000000
# 27.0     230.000000
# 40.0     660.000000
# Name: price, dtype: float64

# %%
plt.hist(mean_price_by_number_of_bathrooms.index, weights=mean_price_by_number_of_bathrooms.values, bins=range(0,45), alpha=0.5)
plt.xlabel('Nombre de salles de bain')
plt.ylabel('Prix moyen')
plt.show()

# %% [markdown]
# **Commentaire** : On voit bien que le prix moyen est le plus élevé lorsque le nombre de salles de bain est égal à **13**.

# %% [markdown]
# ## Question 4 :
#
# Créer une DataFrame qui contient les colonnes suivantes :
#
# - `availability` : les dates de disponibilité possibles (valeurs uniques)
# - `count` : le nombre de biens qui deviennent disponibles à cette date
# - `count_cum`: le nombre de biens cumulés disponibles à cette date
# - `price_mean`: le prix moyen des biens qui deviennent disponibles à cette date
#
# Stocker cette DataFrame dans une table SQL hébergée sur Scalingo nommée data_availability.

# %%
df_availability = pd.DataFrame(sorted(df['availability'].unique()), columns=['availability'])

df_availability = pd.DataFrame(sorted(df['availability'].unique()), columns=['availability'])
df_availability['count'] = 0  
df_availability['count_cum'] = df[df['availability'] == df_availability.loc[0, 'availability']].shape[0]
df_availability.loc[0, 'count'] = df_availability.loc[0, 'count_cum']
df_availability.loc[0, 'price_mean'] = df.groupby('availability')['price'].mean()[df_availability.loc[0, 'availability']]

for index, availability in enumerate(df_availability['availability']):
    if index > 0:
        df_availability.loc[index, 'count'] = df[df['availability'] == availability].shape[0]
        df_availability.loc[index, 'count_cum'] = df_availability.loc[index-1, 'count_cum'] + df_availability.loc[index, 'count']
        df_availability.loc[index, 'price_mean'] = df.groupby('availability')['price'].mean()[availability]


df_availability
# Out:
#    availability  count  count_cum  price_mean
# 0    2023-01-01  10597      10597  115.154591
# 1    2023-01-16      1      10598  110.000000
# 2    2023-01-17      1      10599  139.000000
# 3    2023-01-18     43      10642  160.642209
# 4    2023-01-19     39      10681  367.552051
# ..          ...    ...        ...         ...
# 75   2023-12-18    307      12933   96.820961
# 76   2023-12-19    185      13118  111.379351
# 77   2023-12-20     98      13216   81.913469
# 78   2023-12-21     93      13309   64.648011
# 79   2023-12-22     11      13320   62.100000
#
# [80 rows x 4 columns]

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
#
# df_availability.to_sql('data_availability', engine)

# %% [markdown]
# #### Question 5 :
#
# Représenter la matrice des corrélations des variables quantitatives Vous pouvez vous inspirer de la réponse de Yunununun sur ce thread : https://stackoverflow.com/questions/39409866/correlation-heatmap
#
# Stocker les informations de la matrice des corrélations dans une table SQL hébergée sur Scalingo nommée `correlation_matrix_values` qui contient les colonnes suivant : `variable_1`,  `variable_2`, `coefficient_correlation`.

# %%
import seaborn as sb
corr = df.corr(numeric_only=True)
sb.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <Axes: >

# %%
corr
# Out:
#                 size  total_sqft      bath   balcony     price
# size        1.000000    0.347107  0.898408  0.187291  0.398292
# total_sqft  0.347107    1.000000  0.391148  0.149555  0.573396
# bath        0.898408    0.391148  1.000000  0.204201  0.456345
# balcony     0.187291    0.149555  0.204201  1.000000  0.120355
# price       0.398292    0.573396  0.456345  0.120355  1.000000

# %%
corr_list = []
for i in range(len(corr.columns)):
    for j in range(i):
        corr_list.append({'variable_1': corr.columns[i], 'variable_2': corr.columns[j], 'coefficient_correlation': corr.iloc[i, j]})

df_correlation = pd.DataFrame(corr_list)

df_correlation
# Out:
#    variable_1  variable_2  coefficient_correlation
# 0  total_sqft        size                 0.347107
# 1        bath        size                 0.898408
# 2        bath  total_sqft                 0.391148
# 3     balcony        size                 0.187291
# 4     balcony  total_sqft                 0.149555
# 5     balcony        bath                 0.204201
# 6       price        size                 0.398292
# 7       price  total_sqft                 0.573396
# 8       price        bath                 0.456345
# 9       price     balcony                 0.120355

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
#
# df_correlation.to_sql('correlation_matrix_values', engine)

# %% [markdown]
# # Partie 3 : Prédiction

# %%
import datetime as datetime
from scipy import stats
import statsmodels.api as sm

# %% [markdown]
# ## Question 0 : Découpage du dataset en train et test
#
#
# En fonction du nettoyage, il y a plus ou moins de valeurs nulles.
#
# **Retirer toutes les lignes qui ont au moins une valeur nulle dans une colonne numérique. Stocker ces données dans une table `SQL` hébergée sur Scalingo nommée `data_cleaned_3`.**
#
# En utilisant la méthode `train_test_split` de `sklearn.model_selection` sur les données sans les valeurs manquantes, créer une DataFrame `df_train` contenant 70 % des données et une DataFrame `df_test` contenant 30 % des données. Renseigner l'argument `random_state` et lui donner une valeur de 42.
#
# **Stocker ces données dans deux tables `SQL` hébergées sur Scalingo nommée `train` et `test`.**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df_prediction = df.dropna(subset=['size'])
df_prediction = df_prediction.dropna(subset=['total_sqft'])
df_prediction = df_prediction.dropna(subset=['bath'])
df_prediction = df_prediction.dropna(subset=['balcony'])
df_prediction = df_prediction.dropna(subset=['price'])

df_prediction
# Out:
#                   area_type availability                  location  size  \
# 0      Super built-up  Area   2023-12-19  Electronic City Phase II   2.0
# 1                Plot  Area   2023-01-01          Chikka Tirupathi   4.0
# 2            Built-up  Area   2023-01-01               Uttarahalli   3.0
# 3      Super built-up  Area   2023-01-01        Lingadheeranahalli   3.0
# 4      Super built-up  Area   2023-01-01                  Kothanur   2.0
# ...                     ...          ...                       ...   ...
# 13314  Super built-up  Area   2023-01-01         Green Glen Layout   3.0
# 13315        Built-up  Area   2023-01-01                Whitefield   5.0
# 13317        Built-up  Area   2023-01-01     Raja Rajeshwari Nagar   2.0
# 13318  Super built-up  Area   2023-06-18           Padmanabhanagar   4.0
# 13319  Super built-up  Area   2023-01-01              Doddathoguru   1.0
#
#        society  total_sqft  bath  balcony   price
# 0      Coomee       1056.0   2.0      1.0   39.07
# 1      Theanmp      2600.0   5.0      3.0  120.00
# 2          NaN      1440.0   2.0      3.0   62.00
# 3      Soiewre      1521.0   3.0      1.0   95.00
# 4          NaN      1200.0   2.0      1.0   51.00
# ...        ...         ...   ...      ...     ...
# 13314  SoosePr      1715.0   3.0      3.0  112.00
# 13315  ArsiaEx      3453.0   4.0      0.0  231.00
# 13317  Mahla T      1141.0   2.0      1.0   60.00
# 13318  SollyCl      4689.0   4.0      1.0  488.00
# 13319      NaN       550.0   1.0      1.0   17.00
#
# [12711 rows x 9 columns]

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
#
# df_prediction.to_sql('data_cleaned_3', engine)

# %%
df_train, df_test = train_test_split(df_prediction, test_size=3.0/10.0, random_state=42)

# %%
df_train
# Out:
#                   area_type availability                  location  size  \
# 6733   Super built-up  Area   2023-06-18            Kothnoor Dinne   2.0
# 3620         Built-up  Area   2023-01-01       Devarabeesana Halli   3.0
# 10650  Super built-up  Area   2023-12-18               Thanisandra   3.0
# 12509  Super built-up  Area   2023-01-19                 Hosa Road   3.0
# 1688   Super built-up  Area   2023-01-01                 Yelahanka   2.0
# ...                     ...          ...                       ...   ...
# 12533        Built-up  Area   2023-01-01              Choodasandra   2.0
# 5465   Super built-up  Area   2023-05-18  Electronics City Phase 1   2.0
# 5675   Super built-up  Area   2023-01-01                R.T. Nagar   2.0
# 903    Super built-up  Area   2023-01-01               Hennur Road   3.0
# 7647   Super built-up  Area   2023-01-01          Dodsworth Layout   3.0
#
#        society  total_sqft  bath  balcony  price
# 6733       NaN      1200.0   2.0      2.0   35.0
# 3620   Sorisa       1750.0   3.0      3.0  149.0
# 10650  Bhe 2ko      1732.0   3.0      1.0  112.0
# 12509  Sosisic      1893.0   3.0      2.0  130.0
# 1688       NaN      1150.0   2.0      2.0   46.0
# ...        ...         ...   ...      ...    ...
# 12533  Maidsr       1065.0   2.0      1.0   46.0
# 5465   Shitt S      1175.0   2.0      1.0   69.0
# 5675       NaN       970.0   2.0      1.0   55.0
# 903    SaireSa      1904.0   3.0      2.0  120.0
# 7647   Ciques       1893.0   3.0      2.0  115.0
#
# [8897 rows x 9 columns]

# %%
df_test
# Out:
#                   area_type availability                  location  size  \
# 12716        Built-up  Area   2023-01-01               Thanisandra   3.0
# 10172  Super built-up  Area   2023-04-18                Kudlu Gate   2.0
# 3060   Super built-up  Area   2023-01-01                 Kambipura   2.0
# 319    Super built-up  Area   2023-01-01            Motappa Layout   2.0
# 8353             Plot  Area   2023-01-01    Kengeri Satellite Town   2.0
# ...                     ...          ...                       ...   ...
# 10806        Built-up  Area   2023-01-01               Frazer Town   2.0
# 4133   Super built-up  Area   2023-01-01                HSR Layout   3.0
# 3980   Super built-up  Area   2023-04-18  Electronic City Phase II   3.0
# 9896   Super built-up  Area   2023-01-01              Malleshwaram   1.0
# 3073             Plot  Area   2023-02-18                 T c palya   3.0
#
#        society  total_sqft  bath  balcony   price
# 12716  Soitya       1694.0   3.0      1.0  125.00
# 10172  SunetSo       940.0   2.0      1.0   69.57
# 3060   Prrtht        883.0   2.0      1.0   45.00
# 319    Puodse       1113.0   2.0      1.0   51.00
# 8353       NaN      2480.0   2.0      1.0  160.00
# ...        ...         ...   ...      ...     ...
# 10806      NaN      1200.0   2.0      1.0   78.00
# 4133   RotatHa      1600.0   2.0      2.0  115.00
# 3980   MJtroty      1329.0   2.0      2.0   41.00
# 9896       NaN       620.0   1.0      1.0   86.80
# 3073       NaN      1500.0   2.0      0.0   85.00
#
# [3814 rows x 9 columns]

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
# df_train.to_sql('train', engine)
#
# df_test.to_sql('test', engine)

# %% [markdown]
# ## Question 1 :  Prédiction avec une variable numérique
# ### a. Un premier modèle
#
# On veut entraîner un modèle de régression linéaire de la forme $Y = a \times X$ où $Y$ est le prix et $X$ la surface. Cela reviendrait à dire que le prix est uniquement dépendant de la surface $X$ et du coefficient $a$ (qui serait le prix au mètre carré) ce qui est bien sûr une approximation (mais une approximation intéressante).
#
# Entraîner un modèle de régression linéaire avec pour $X$ la variable `total_sqft` et pour $Y$  la variable `price` en utilisant `sklearn` sur la DataFrame `df_train` (l'argument `fit_intercept` peut valoir `True` ou `False` à votre convenance).
#
# Calculer les prédictions `y_pred_test` sur la DataFrame de `test`. Stocker ces prédictions dans une table `model_1_predictions` qui contient les colonnes :
# - `index` (l'index de la DataFrame originelle)
# - `total_sqft` (la valeur de `total_sqft`)
# - `price` : la vraie valeur du prix
# - `price_pred` :  la valeur de la prédiction.

# %%
# Extraire la variable d'entrée (toutes les lignes, la colonne total_sqft)
X = df_train[['total_sqft']]

# Extraire la colonne de sortie (toutes les lignes, la colonne price)
Y = df_train['price']

# %%
model = LinearRegression(fit_intercept=True)
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
X_test = df_test[['total_sqft']]

y_pred_test = model.predict(X_test)

# %%
df_test
# Out:
#                   area_type availability                  location  size  \
# 12716        Built-up  Area   2023-01-01               Thanisandra   3.0
# 10172  Super built-up  Area   2023-04-18                Kudlu Gate   2.0
# 3060   Super built-up  Area   2023-01-01                 Kambipura   2.0
# 319    Super built-up  Area   2023-01-01            Motappa Layout   2.0
# 8353             Plot  Area   2023-01-01    Kengeri Satellite Town   2.0
# ...                     ...          ...                       ...   ...
# 10806        Built-up  Area   2023-01-01               Frazer Town   2.0
# 4133   Super built-up  Area   2023-01-01                HSR Layout   3.0
# 3980   Super built-up  Area   2023-04-18  Electronic City Phase II   3.0
# 9896   Super built-up  Area   2023-01-01              Malleshwaram   1.0
# 3073             Plot  Area   2023-02-18                 T c palya   3.0
#
#        society  total_sqft  bath  balcony   price
# 12716  Soitya       1694.0   3.0      1.0  125.00
# 10172  SunetSo       940.0   2.0      1.0   69.57
# 3060   Prrtht        883.0   2.0      1.0   45.00
# 319    Puodse       1113.0   2.0      1.0   51.00
# 8353       NaN      2480.0   2.0      1.0  160.00
# ...        ...         ...   ...      ...     ...
# 10806      NaN      1200.0   2.0      1.0   78.00
# 4133   RotatHa      1600.0   2.0      2.0  115.00
# 3980   MJtroty      1329.0   2.0      2.0   41.00
# 9896       NaN       620.0   1.0      1.0   86.80
# 3073       NaN      1500.0   2.0      0.0   85.00
#
# [3814 rows x 9 columns]

# %%
df_train
# Out:
#                   area_type availability                  location  size  \
# 6733   Super built-up  Area   2023-06-18            Kothnoor Dinne   2.0
# 3620         Built-up  Area   2023-01-01       Devarabeesana Halli   3.0
# 10650  Super built-up  Area   2023-12-18               Thanisandra   3.0
# 12509  Super built-up  Area   2023-01-19                 Hosa Road   3.0
# 1688   Super built-up  Area   2023-01-01                 Yelahanka   2.0
# ...                     ...          ...                       ...   ...
# 12533        Built-up  Area   2023-01-01              Choodasandra   2.0
# 5465   Super built-up  Area   2023-05-18  Electronics City Phase 1   2.0
# 5675   Super built-up  Area   2023-01-01                R.T. Nagar   2.0
# 903    Super built-up  Area   2023-01-01               Hennur Road   3.0
# 7647   Super built-up  Area   2023-01-01          Dodsworth Layout   3.0
#
#        society  total_sqft  bath  balcony  price
# 6733       NaN      1200.0   2.0      2.0   35.0
# 3620   Sorisa       1750.0   3.0      3.0  149.0
# 10650  Bhe 2ko      1732.0   3.0      1.0  112.0
# 12509  Sosisic      1893.0   3.0      2.0  130.0
# 1688       NaN      1150.0   2.0      2.0   46.0
# ...        ...         ...   ...      ...    ...
# 12533  Maidsr       1065.0   2.0      1.0   46.0
# 5465   Shitt S      1175.0   2.0      1.0   69.0
# 5675       NaN       970.0   2.0      1.0   55.0
# 903    SaireSa      1904.0   3.0      2.0  120.0
# 7647   Ciques       1893.0   3.0      2.0  115.0
#
# [8897 rows x 9 columns]

# %%
predictions = df_test.copy()
predictions['price_pred'] = y_pred_test

modele_1_predictions = predictions[['total_sqft', 'price', 'price_pred']]
modele_1_predictions
# Out:
#        total_sqft   price  price_pred
# 12716      1694.0  125.00  119.260966
# 10172       940.0   69.57   66.285522
# 3060        883.0   45.00   62.280747
# 319        1113.0   51.00   78.440365
# 8353       2480.0  160.00  174.484704
# ...           ...     ...         ...
# 10806      1200.0   78.00   84.552917
# 4133       1600.0  115.00  112.656600
# 3980       1329.0   41.00   93.616354
# 9896        620.0   86.80   43.802575
# 3073       1500.0   85.00  105.630679
#
# [3814 rows x 3 columns]

# %% [markdown]
# ### Diagnostics

# %%
# Histogram of residuals
residuals = df_test['price'] - modele_1_predictions['price_pred']
sb.histplot(residuals)
plt.xlabel('Residual value')
plt.ylabel('Frequency')
plt.show()

# %%
mu, std = stats.norm.fit(residuals)
mu, std
# Out:
# (-0.49109368999279684, 116.37966030333104)

# %% [markdown]
# **Commentaire** : La valeur moyenne négative suggère qu'en moyenne, notre modèle surestime légèrement la variable cible (le prix). Cependant, elle est très proche de zéro, ce qui indique que les prédictions du modèle sont relativement non biaisées. L'écart-type légérement grande suggère qu'il existe une certaine variabilité dans les prévisions du modèle.

# %%
fig, ax = plt.subplots()
# plot the residuals
sb.histplot(x=residuals, ax=ax, stat="density", linewidth=0, kde=True)
ax.set(title="Distribution of residuals", xlabel="residual")

# plot corresponding normal curve
xmin, xmax = plt.xlim() # the maximum x values from the histogram above
x = np.linspace(xmin, xmax, 100) # generate some x values
p = stats.norm.pdf(x, mu, std) # calculate the y values for the normal curve
sb.lineplot(x=x, y=p, color="orange", ax=ax)
plt.show()

# %% [markdown]
# **Commentaires** :
# Ce graphique fournit une représentation visuelle de la distribution des résidus et la compare à une distribution normale ayant la même moyenne (mu) et le même écart-type (std) que les résidus.
#
# La distribution des résidus présente un pic plus élevé que la distribution normale, cela indique que les résidus sont plus étroitement regroupés autour de la moyenne, ce qui se traduit par une distribution dont l'aplatissement est plus élevé que la distribution normale. Cette distribution est souvent appelée distribution leptokurtique.
#
# Une distribution leptokurtique suggère que notre modèle peut être plus performant dans certains domaines (où les résidus sont étroitement regroupés autour de zéro) mais peut avoir des queues plus lourdes, indiquant la présence de valeurs aberrantes ou extrêmes que le modèle ne capture pas bien.

# %%
# Boxplot of residuals
sb.boxplot(x=residuals, showmeans=True);

# %%
# Fit plot
Y_max = df_test['price'].max()
Y_min = df_test['price'].min()

ax = sb.scatterplot(x=df_test['price'], y=modele_1_predictions['price_pred'])
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Observed value of Price")
ax.set_ylabel("Predicted value of Price")

X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()

# %% [markdown]
# **Commentaire** :  Idéalement, on aurait voulu observer une distribution égale centrée le plus possible autour de la première diagonale. Certaines predictions, comme on le voit sont donc assez loin de la droite, ce qui renforce notre première observation sur la grande variabilité des résidus.
#
# De plus, au vu de comment la majorité des points sont concentrés dans le coin en bas à gauche, il est difficile de dire exactement est ce que la majorité des points se trouve au dessus ou en dessous de la droite, pour confirmer si effectivement notre modèle a tendance à légèrement surestimer le prix.

# %%
plt.scatter(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.scatter(sorted(df_test.index), modele_1_predictions['price_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %%
plt.plot(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.plot(sorted(df_test.index), modele_1_predictions['price_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %% [markdown]
# **Commentaire** : Représentations graphiques (nuages de points et plots) des prédictions du modèle **(en bleu)** sur les données de test **(en rouge)**

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
# modele_1_predictions.to_sql('modele_1_predictions', engine)

# %% [markdown]
# ### b. Un second modèle
#
# Crée une variable qui est égale au nombre de jours à attendre avant que le bien soit disponible. On nomme cette variable `days_before`.
# Faire de même qu'en a. avec la variable `days_before` pour $X$ (à la place de `total_sqft`).

# %%
today =  datetime.date(2023, 1, 1)
today = pd.to_datetime(today)
df_train['days_before'] = (df_train['availability'] - today).dt.total_seconds() / 86400.0
df_train
# Out:
#                   area_type availability                  location  size  \
# 6733   Super built-up  Area   2023-06-18            Kothnoor Dinne   2.0
# 3620         Built-up  Area   2023-01-01       Devarabeesana Halli   3.0
# 10650  Super built-up  Area   2023-12-18               Thanisandra   3.0
# 12509  Super built-up  Area   2023-01-19                 Hosa Road   3.0
# 1688   Super built-up  Area   2023-01-01                 Yelahanka   2.0
# ...                     ...          ...                       ...   ...
# 12533        Built-up  Area   2023-01-01              Choodasandra   2.0
# 5465   Super built-up  Area   2023-05-18  Electronics City Phase 1   2.0
# 5675   Super built-up  Area   2023-01-01                R.T. Nagar   2.0
# 903    Super built-up  Area   2023-01-01               Hennur Road   3.0
# 7647   Super built-up  Area   2023-01-01          Dodsworth Layout   3.0
#
#        society  total_sqft  bath  balcony  price  days_before
# 6733       NaN      1200.0   2.0      2.0   35.0        168.0
# 3620   Sorisa       1750.0   3.0      3.0  149.0          0.0
# 10650  Bhe 2ko      1732.0   3.0      1.0  112.0        351.0
# 12509  Sosisic      1893.0   3.0      2.0  130.0         18.0
# 1688       NaN      1150.0   2.0      2.0   46.0          0.0
# ...        ...         ...   ...      ...    ...          ...
# 12533  Maidsr       1065.0   2.0      1.0   46.0          0.0
# 5465   Shitt S      1175.0   2.0      1.0   69.0        137.0
# 5675       NaN       970.0   2.0      1.0   55.0          0.0
# 903    SaireSa      1904.0   3.0      2.0  120.0          0.0
# 7647   Ciques       1893.0   3.0      2.0  115.0          0.0
#
# [8897 rows x 10 columns]

# %%
df_test['days_before'] = (df_test['availability'] - today).dt.total_seconds() / 86400.0
df_test
# Out:
#                   area_type availability                  location  size  \
# 12716        Built-up  Area   2023-01-01               Thanisandra   3.0
# 10172  Super built-up  Area   2023-04-18                Kudlu Gate   2.0
# 3060   Super built-up  Area   2023-01-01                 Kambipura   2.0
# 319    Super built-up  Area   2023-01-01            Motappa Layout   2.0
# 8353             Plot  Area   2023-01-01    Kengeri Satellite Town   2.0
# ...                     ...          ...                       ...   ...
# 10806        Built-up  Area   2023-01-01               Frazer Town   2.0
# 4133   Super built-up  Area   2023-01-01                HSR Layout   3.0
# 3980   Super built-up  Area   2023-04-18  Electronic City Phase II   3.0
# 9896   Super built-up  Area   2023-01-01              Malleshwaram   1.0
# 3073             Plot  Area   2023-02-18                 T c palya   3.0
#
#        society  total_sqft  bath  balcony   price  days_before
# 12716  Soitya       1694.0   3.0      1.0  125.00          0.0
# 10172  SunetSo       940.0   2.0      1.0   69.57        107.0
# 3060   Prrtht        883.0   2.0      1.0   45.00          0.0
# 319    Puodse       1113.0   2.0      1.0   51.00          0.0
# 8353       NaN      2480.0   2.0      1.0  160.00          0.0
# ...        ...         ...   ...      ...     ...          ...
# 10806      NaN      1200.0   2.0      1.0   78.00          0.0
# 4133   RotatHa      1600.0   2.0      2.0  115.00          0.0
# 3980   MJtroty      1329.0   2.0      2.0   41.00        107.0
# 9896       NaN       620.0   1.0      1.0   86.80          0.0
# 3073       NaN      1500.0   2.0      0.0   85.00         48.0
#
# [3814 rows x 10 columns]

# %%
# Extraire la variable d'entrée (toutes les lignes, la colonne days_before)
X = df_train[['days_before']]

# Extraire la colonne de sortie (toutes les lignes, la colonne price)
Y = df_train['price']

# %%
model = LinearRegression(fit_intercept=True)
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
X_test = df_test[['days_before']]

y_pred_test = model.predict(X_test)

# %%
predictions = df_test.copy()
predictions['price_pred'] = y_pred_test

modele_1_bis_predictions = predictions[['days_before', 'price', 'price_pred']]
modele_1_bis_predictions
# Out:
#        days_before   price  price_pred
# 12716          0.0  125.00  108.646762
# 10172        107.0   69.57  101.499525
# 3060           0.0   45.00  108.646762
# 319            0.0   51.00  108.646762
# 8353           0.0  160.00  108.646762
# ...            ...     ...         ...
# 10806          0.0   78.00  108.646762
# 4133           0.0  115.00  108.646762
# 3980         107.0   41.00  101.499525
# 9896           0.0   86.80  108.646762
# 3073          48.0   85.00  105.440525
#
# [3814 rows x 3 columns]

# %% [markdown]
# ### Diagnostics

# %%
# Histogram of residuals
residuals = df_test['price'] - modele_1_bis_predictions['price_pred']
sb.histplot(residuals)
plt.xlabel('Residual value')
plt.ylabel('Frequency')
plt.show()

# %%
mu, std = stats.norm.fit(residuals)
mu, std
# Out:
# (0.9728954536010636, 131.97512364374802)

# %% [markdown]
# **Commentaire**: La valeur moyenne postive suggère qu'en moyenne, notre modèle a tendance à sous-estimer légèrement la variable cible (le prix), à l'inverse du premier modèle. Elle est aussi proche de zéro mais moins que la moyenne de distribution des résidus du modèle précedent. L'écart-type est plus grand. On aurait voulu diminuer la variabilité dans les prévisions du modèle.

# %%
fig, ax = plt.subplots()
# plot the residuals
sb.histplot(x=residuals, ax=ax, stat="density", linewidth=0, kde=True)
ax.set(title="Distribution of residuals", xlabel="residual")

# plot corresponding normal curve
xmin, xmax = plt.xlim() # the maximum x values from the histogram above
x = np.linspace(xmin, xmax, 100) # generate some x values
p = stats.norm.pdf(x, mu, std) # calculate the y values for the normal curve
sb.lineplot(x=x, y=p, color="orange", ax=ax)
plt.show()

# %%
# Boxplot of residuals
sb.boxplot(x=residuals, showmeans=True);

# %%
# Fit plot
Y_max = df_test['price'].max()
Y_min = df_test['price'].min()

ax = sb.scatterplot(x=df_test['price'], y=modele_1_bis_predictions['price_pred'])
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Observed value of Price")
ax.set_ylabel("Predicted value of Price")

X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()

# %% [markdown]
# **Commentaire** : Dans ce cas ci, il est clair qu'il existe beaucoup plus de points en dessous de la première diagonale, ce qui confirme que notre modèle sous-estime bien la vraie valeur du prix sur les données de test.
# Aussi, les points sont très loin d'être groupés autour de la droite, la variable ```days_before``` produit des performances moins bonnes que ```total_sqft```

# %%
plt.scatter(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.scatter(sorted(df_test.index), modele_1_bis_predictions['price_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %%
plt.plot(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.plot(sorted(df_test.index), modele_1_bis_predictions['price_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %% [markdown]
# **Commentaire** : Représentations graphiques (nuages de points et plots) des prédictions du modèle **(en bleu)** sur les données de test **(en rouge)**

# %% [markdown]
# ## Question 2 : Prédiction avec plusieurs variables numériques**
#
# On veut entraîner un modèle de régression linéaire de la forme $ Y = a_1 \times X_1 + a_2 \times X_2 + ....$ où $Y$ est le prix et $X_1$, $X_2$ ... sont des variables quantitatives parmi la surface, le nombre de pièces, le nombre de balcons, le nombre de salle de bains et le nombre de jours).
#
# Entraîner un modèle de régression linéaire avec toutes les variables numériques autres que le prix pour $X$ et pour $Y$  la variable `price` en utilisant `sklearn` sur la DataFrame `df_train` (l'argument `fit_intercept` peut valoir `True` ou `False` à votre convenance).
#
# Calculer les prédictions `y_pred_test` sur la DataFrame de `test`. Stocker ces prédictions dans une table `model_2_predictions` qui contient les colonnes :
# - `index` (l'index de la DataFrame originelle)
# - `total_sqft` (la valeur de `total_sqft`)
# - `price` : la vraie valeur du prix
# - `price_pred` :  la valeur de la prédiction.

# %%
# Extraire la variable d'entrée (toutes les lignes, les colonnes size, total_sqft, bath, balcony, days_before)
X = df_train[['size', 'total_sqft', 'bath', 'balcony', 'days_before']]

# Extraire la colonne de sortie (toutes les lignes, la colonne price)
Y = df_train['price']

# %%
model = LinearRegression(fit_intercept=True)
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
X_test = df_test[['size', 'total_sqft', 'bath', 'balcony', 'days_before']]

y_mlr_pred_test = model.predict(X_test)

# %%
predictions = df_test.copy()
predictions['price_mlr_pred'] = y_mlr_pred_test

modele_2_predictions = predictions[['size', 'total_sqft', 'bath', 'balcony', 'days_before', 'price', 'price_mlr_pred']]
modele_2_predictions
# Out:
#        size  total_sqft  bath  balcony  days_before   price  price_mlr_pred
# 12716   3.0      1694.0   3.0      1.0          0.0  125.00      128.916411
# 10172   2.0       940.0   2.0      1.0        107.0   69.57       56.009283
# 3060    2.0       883.0   2.0      1.0          0.0   45.00       55.769502
# 319     2.0      1113.0   2.0      1.0          0.0   51.00       69.165124
# 8353    2.0      2480.0   2.0      1.0          0.0  160.00      148.781709
# ...     ...         ...   ...      ...          ...     ...             ...
# 10806   2.0      1200.0   2.0      1.0          0.0   78.00       74.232163
# 4133    3.0      1600.0   2.0      2.0          0.0  115.00       96.104272
# 3980    3.0      1329.0   2.0      2.0        107.0   41.00       77.240731
# 9896    1.0       620.0   1.0      1.0          0.0   86.80       14.539118
# 3073    3.0      1500.0   2.0      0.0         48.0   85.00       92.094413
#
# [3814 rows x 7 columns]

# %% [markdown]
# ### **Diagnostics**

# %%
# Histogram of residuals
residuals = df_test['price'] - modele_2_predictions['price_mlr_pred']
sb.histplot(residuals)
plt.xlabel('Residual value')
plt.ylabel('Frequency')
plt.show()

# %%
mu, std = stats.norm.fit(residuals)
mu, std
# Out:
# (0.1135359927399511, 107.71319665100802)

# %% [markdown]
# **Commentaire** : Pour notre modèle de regression linéaire multiple, on obtient un meilleur couple (mu, std) que nos deux modèles linéaires precedents. La moyenne est très proche de zéro et l'écart type de la distribution des résidus est plus bas que ce qu'on avait obtenu sur les deux dernières regressions.

# %%
fig, ax = plt.subplots()
# plot the residuals
sb.histplot(x=residuals, ax=ax, stat="density", linewidth=0, kde=True)
ax.set(title="Distribution of residuals", xlabel="residual")

# plot corresponding normal curve
xmin, xmax = plt.xlim() # the maximum x values from the histogram above
x = np.linspace(xmin, xmax, 100) # generate some x values
p = stats.norm.pdf(x, mu, std) # calculate the y values for the normal curve
sb.lineplot(x=x, y=p, color="orange", ax=ax)
plt.show()

# %% [markdown]
# **Commentaire** : Bien qu'on ait reussi à baisser l'écart-type, on voit bien qu'il toujours légèrement plus élevé qu'on le voudrait, donc on prédit toujours assez mal les cas extrèmes, éloignés de la moyenne.

# %%
# Boxplot of residuals
sb.boxplot(x=residuals, showmeans=True);

# %%
# Fit plot
Y_max = df_test['price'].max()
Y_min = df_test['price'].min()

ax = sb.scatterplot(x=df_test['price'], y=modele_2_predictions['price_mlr_pred'])
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Observed value of Price")
ax.set_ylabel("Predicted value of Price")

X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()

# %% [markdown]
# **Commentaire**: Le fit plot révèle bien les écarts dans la prédiction et les données de test. Mais on voit aussi qu'en moyenne, on a pas de tendance significative à la surestimation ou sous-estimation de la variable cible.

# %%
plt.scatter(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.scatter(sorted(df_test.index), modele_2_predictions['price_mlr_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %%
plt.plot(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.plot(sorted(df_test.index), modele_2_predictions['price_mlr_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %% [markdown]
# **Commentaire** : Représentations graphiques (nuages de points et plots) des prédictions du modèle **(en bleu)** sur les données de test **(en rouge)**

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
# modele_2_predictions.to_sql('modele_2_predictions', engine)

# %% [markdown]
# ## Question 3 :  Prédiction avec plusieurs variables numériques et une catégorie
#
# Include une variable catégorielle dans le modèle de régression linéaire en utilisant `pandas.get_dummies`. Vous pourrez vous inspirer de : https://www.sfu.ca/~mjbrydon/tutorials/BAinPy/10_multiple_regression.html
#
# Reproduire la table de la question précédente avec le nouveau modèle et appeler cette table `model_3_predictions`

# %% [markdown]
# #### On utilise **area_type** comme variable catégorielle

# %%
# Turning the area_type column into a category type
df_train['area_type'] = df_train['area_type'].astype('category')
df_test['area_type'] = df_test['area_type'].astype('category')
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8897 entries, 6733 to 7647
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     8897 non-null   category
#  1   availability  8897 non-null   datetime64[ns]
#  2   location      8897 non-null   object
#  3   size          8897 non-null   float64
#  4   society       5313 non-null   object
#  5   total_sqft    8897 non-null   float64
#  6   bath          8897 non-null   float64
#  7   balcony       8897 non-null   float64
#  8   price         8897 non-null   float64
#  9   days_before   8897 non-null   float64
# dtypes: category(1), datetime64[ns](1), float64(6), object(2)
# memory usage: 704.0+ KB

# %%
# Extraire la variable d'entrée (toutes les lignes, les colonnes size, total_sqft, bath, balcony, days_before)
X = df_train[['size', 'total_sqft', 'bath', 'balcony', 'days_before']]

# Extraire la colonne de sortie (toutes les lignes, la colonne price)
Y = df_train['price']

# %%
# Create a matrix of dummy variables
area_type_d = pd.get_dummies(df_train['area_type'])
area_type_d
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 6733                0             0           0                     1
# 3620                1             0           0                     0
# 10650               0             0           0                     1
# 12509               0             0           0                     1
# 1688                0             0           0                     1
# ...               ...           ...         ...                   ...
# 12533               1             0           0                     0
# 5465                0             0           0                     1
# 5675                0             0           0                     1
# 903                 0             0           0                     1
# 7647                0             0           0                     1
#
# [8897 rows x 4 columns]

# %%
# Adding the dummy columns to the existing X matrix
fullX = pd.concat([X, area_type_d['Built-up  Area']], axis=1)
fullX = pd.concat([fullX, area_type_d['Carpet  Area']], axis=1)
fullX = pd.concat([fullX, area_type_d['Plot  Area']], axis=1)
fullX = pd.concat([fullX, area_type_d['Super built-up  Area']], axis=1)
fullX
# Out:
#        size  total_sqft  bath  balcony  days_before  Built-up  Area  \
# 6733    2.0      1200.0   2.0      2.0        168.0               0
# 3620    3.0      1750.0   3.0      3.0          0.0               1
# 10650   3.0      1732.0   3.0      1.0        351.0               0
# 12509   3.0      1893.0   3.0      2.0         18.0               0
# 1688    2.0      1150.0   2.0      2.0          0.0               0
# ...     ...         ...   ...      ...          ...             ...
# 12533   2.0      1065.0   2.0      1.0          0.0               1
# 5465    2.0      1175.0   2.0      1.0        137.0               0
# 5675    2.0       970.0   2.0      1.0          0.0               0
# 903     3.0      1904.0   3.0      2.0          0.0               0
# 7647    3.0      1893.0   3.0      2.0          0.0               0
#
#        Carpet  Area  Plot  Area  Super built-up  Area
# 6733              0           0                     1
# 3620              0           0                     0
# 10650             0           0                     1
# 12509             0           0                     1
# 1688              0           0                     1
# ...             ...         ...                   ...
# 12533             0           0                     0
# 5465              0           0                     1
# 5675              0           0                     1
# 903               0           0                     1
# 7647              0           0                     1
#
# [8897 rows x 9 columns]

# %%
X_test = df_test[['size', 'total_sqft', 'bath', 'balcony', 'days_before']]
area_type_test_d = pd.get_dummies(df_test['area_type'])
fullX_test = pd.concat([X_test, area_type_test_d['Built-up  Area']], axis=1)
fullX_test = pd.concat([fullX_test, area_type_test_d['Carpet  Area']], axis=1)
fullX_test = pd.concat([fullX_test, area_type_test_d['Plot  Area']], axis=1)
fullX_test = pd.concat([fullX_test, area_type_test_d['Super built-up  Area']], axis=1)
fullX_test
# Out:
#        size  total_sqft  bath  balcony  days_before  Built-up  Area  \
# 12716   3.0      1694.0   3.0      1.0          0.0               1
# 10172   2.0       940.0   2.0      1.0        107.0               0
# 3060    2.0       883.0   2.0      1.0          0.0               0
# 319     2.0      1113.0   2.0      1.0          0.0               0
# 8353    2.0      2480.0   2.0      1.0          0.0               0
# ...     ...         ...   ...      ...          ...             ...
# 10806   2.0      1200.0   2.0      1.0          0.0               1
# 4133    3.0      1600.0   2.0      2.0          0.0               0
# 3980    3.0      1329.0   2.0      2.0        107.0               0
# 9896    1.0       620.0   1.0      1.0          0.0               0
# 3073    3.0      1500.0   2.0      0.0         48.0               0
#
#        Carpet  Area  Plot  Area  Super built-up  Area
# 12716             0           0                     0
# 10172             0           0                     1
# 3060              0           0                     1
# 319               0           0                     1
# 8353              0           1                     0
# ...             ...         ...                   ...
# 10806             0           0                     0
# 4133              0           0                     1
# 3980              0           0                     1
# 9896              0           0                     1
# 3073              0           1                     0
#
# [3814 rows x 9 columns]

# %%
model = LinearRegression(fit_intercept=True)
model_result = model.fit(fullX, Y)
model_result
# Out:
# LinearRegression()

# %%
y_mlr_pred_test = model.predict(fullX_test)

# %%
predictions = df_test.copy()
predictions['price_mlr_pred'] = y_mlr_pred_test

modele_3_predictions = predictions[['size', 'total_sqft', 'bath', 'balcony', 'days_before', 'area_type', 'price', 'price_mlr_pred']]
modele_3_predictions
# Out:
#        size  total_sqft  bath  balcony  days_before             area_type  \
# 12716   3.0      1694.0   3.0      1.0          0.0        Built-up  Area
# 10172   2.0       940.0   2.0      1.0        107.0  Super built-up  Area
# 3060    2.0       883.0   2.0      1.0          0.0  Super built-up  Area
# 319     2.0      1113.0   2.0      1.0          0.0  Super built-up  Area
# 8353    2.0      2480.0   2.0      1.0          0.0            Plot  Area
# ...     ...         ...   ...      ...          ...                   ...
# 10806   2.0      1200.0   2.0      1.0          0.0        Built-up  Area
# 4133    3.0      1600.0   2.0      2.0          0.0  Super built-up  Area
# 3980    3.0      1329.0   2.0      2.0        107.0  Super built-up  Area
# 9896    1.0       620.0   1.0      1.0          0.0  Super built-up  Area
# 3073    3.0      1500.0   2.0      0.0         48.0            Plot  Area
#
#         price  price_mlr_pred
# 12716  125.00      112.993866
# 10172   69.57       49.350196
# 3060    45.00       46.444644
# 319     51.00       60.099743
# 8353   160.00      214.225119
# ...       ...             ...
# 10806   78.00       66.997382
# 4133   115.00       86.224754
# 3980    41.00       69.656948
# 9896    86.80       14.162629
# 3073    85.00      144.799858
#
# [3814 rows x 8 columns]

# %% [markdown]
# ### **Diagnostics**

# %%
# Histogram of residuals
residuals = df_test['price'] - modele_3_predictions['price_mlr_pred']
sb.histplot(residuals)
plt.xlabel('Residual value')
plt.ylabel('Frequency')
plt.show()

# %%
mu, std = stats.norm.fit(residuals)
mu, std
# Out:
# (-0.28582863558749455, 107.18344747960711)

# %% [markdown]
# **Commentaire** : Si on compare à la dernière regression multiple, on n'obtient pas nécessairement un meilleur couple (mu, std) pour la distribution des résidus. On a néanmoins une légère tendance à surestimer la valeur cible sans trop nous élogner de d'un mu de 0. L'écart-type reste à peu près la même que la pour la dernière linéaire regression multiple.

# %%
fig, ax = plt.subplots()
# plot the residuals
sb.histplot(x=residuals, ax=ax, stat="density", linewidth=0, kde=True)
ax.set(title="Distribution of residuals", xlabel="residual")

# plot corresponding normal curve
xmin, xmax = plt.xlim() # the maximum x values from the histogram above
x = np.linspace(xmin, xmax, 100) # generate some x values
p = stats.norm.pdf(x, mu, std) # calculate the y values for the normal curve
sb.lineplot(x=x, y=p, color="orange", ax=ax)
plt.show()

# %% [markdown]
# **Commentaire** : On a le même type de distribution des résidus, prédiction très peu biaisées mais difficultés à prédire les valeurs extrêmes.

# %%
# Boxplot of residuals
sb.boxplot(x=residuals, showmeans=True);

# %%
# Fit plot
Y_max = df_test['price'].max()
Y_min = df_test['price'].min()

ax = sb.scatterplot(x=df_test['price'], y=modele_3_predictions['price_mlr_pred'])
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Observed value of Price")
ax.set_ylabel("Predicted value of Price")

X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()

# %% [markdown]
# **Commentaire** : Le fit plot révèle bien les écarts dans la prédiction et les données de test. Mais on voit aussi qu'en moyenne, on a pas de tendance significative à la surestimation ou sous-estimation de la variable cible.

# %%
plt.plot(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.plot(sorted(df_test.index), modele_3_predictions['price_mlr_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %%
plt.scatter(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.scatter(sorted(df_test.index), modele_3_predictions['price_mlr_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %% [markdown]
# **Commentaire** : Représentations graphiques (nuages de points et plots) des prédictions du modèle **(en bleu)** sur les données de test **(en rouge)**

# %% [markdown]
# #### À executer pour ajouter dans la base Scalingo
# modele_3_predictions.to_sql('modele_3_predictions', engine)

# %% [markdown]
# #### On utilise **location** comme variable catégorielle

# %%
# Turning location into a category type
df_train['location'] = df_train['location'].astype('category')
df_test['location'] = df_test['location'].astype('category')
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8897 entries, 6733 to 7647
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     8897 non-null   category
#  1   availability  8897 non-null   datetime64[ns]
#  2   location      8897 non-null   category
#  3   size          8897 non-null   float64
#  4   society       5313 non-null   object
#  5   total_sqft    8897 non-null   float64
#  6   bath          8897 non-null   float64
#  7   balcony       8897 non-null   float64
#  8   price         8897 non-null   float64
#  9   days_before   8897 non-null   float64
# dtypes: category(2), datetime64[ns](1), float64(6), object(1)
# memory usage: 692.8+ KB

# %%
# Create a matrix of dummy variables
location_d = pd.get_dummies(df_train['location'])
location_d
# Out:
#         Anekal   Basavangudi   Bhoganhalli   Devarabeesana Halli  \
# 6733         0             0             0                     0
# 3620         0             0             0                     1
# 10650        0             0             0                     0
# 12509        0             0             0                     0
# 1688         0             0             0                     0
# ...        ...           ...           ...                   ...
# 12533        0             0             0                     0
# 5465         0             0             0                     0
# 5675         0             0             0                     0
# 903          0             0             0                     0
# 7647         0             0             0                     0
#
#         Devarachikkanahalli   Electronic City   Mysore Highway   Rachenahalli  \
# 6733                      0                 0                0              0
# 3620                      0                 0                0              0
# 10650                     0                 0                0              0
# 12509                     0                 0                0              0
# 1688                      0                 0                0              0
# ...                     ...               ...              ...            ...
# 12533                     0                 0                0              0
# 5465                      0                 0                0              0
# 5675                      0                 0                0              0
# 903                       0                 0                0              0
# 7647                      0                 0                0              0
#
#         Sector 1 HSR Layout   Thanisandra  ...  manyata tech park  \
# 6733                      0             0  ...                  0
# 3620                      0             0  ...                  0
# 10650                     0             0  ...                  0
# 12509                     0             0  ...                  0
# 1688                      0             0  ...                  0
# ...                     ...           ...  ...                ...
# 12533                     0             0  ...                  0
# 5465                      0             0  ...                  0
# 5675                      0             0  ...                  0
# 903                       0             0  ...                  0
# 7647                      0             0  ...                  0
#
#        mvj engineering college  near Ramanashree California resort  rr nagar  \
# 6733                         0                                   0         0
# 3620                         0                                   0         0
# 10650                        0                                   0         0
# 12509                        0                                   0         0
# 1688                         0                                   0         0
# ...                        ...                                 ...       ...
# 12533                        0                                   0         0
# 5465                         0                                   0         0
# 5675                         0                                   0         0
# 903                          0                                   0         0
# 7647                         0                                   0         0
#
#        sapthagiri Layout  singapura paradise  t.c palya  tc.palya  \
# 6733                   0                   0          0         0
# 3620                   0                   0          0         0
# 10650                  0                   0          0         0
# 12509                  0                   0          0         0
# 1688                   0                   0          0         0
# ...                  ...                 ...        ...       ...
# 12533                  0                   0          0         0
# 5465                   0                   0          0         0
# 5675                   0                   0          0         0
# 903                    0                   0          0         0
# 7647                   0                   0          0         0
#
#        vinayakanagar  whitefiled
# 6733               0           0
# 3620               0           0
# 10650              0           0
# 12509              0           0
# 1688               0           0
# ...              ...         ...
# 12533              0           0
# 5465               0           0
# 5675               0           0
# 903                0           0
# 7647               0           0
#
# [8897 rows x 1114 columns]

# %%
df_train['location'].unique()
# Out:
# ['Kothnoor Dinne', ' Devarabeesana Halli', 'Thanisandra', 'Hosa Road', 'Yelahanka', ..., 'Someshwara Layout', 'Shetty Halli', 'Jeevanhalli', 'KEB Colony', 'Esther Enclave Layout']
# Length: 1114
# Categories (1114, object): [' Anekal', ' Basavangudi', ' Bhoganhalli', ' Devarabeesana Halli', ..., 't.c palya', 'tc.palya', 'vinayakanagar', 'whitefiled']

# %%
# Extraire la variable d'entrée (toutes les lignes, les colonnes size, total_sqft, bath, balcony, days_before)
X = df_train[['size', 'total_sqft', 'bath', 'balcony', 'days_before']]

# Extraire la colonne de sortie (toutes les lignes, la colonne price)
Y = df_train['price']

# %%
# Ajout des colonnes dummy à la matrice fullX existante
fullX = pd.concat([X, location_d], axis=1)
fullX
# Out:
#        size  total_sqft  bath  balcony  days_before   Anekal   Basavangudi  \
# 6733    2.0      1200.0   2.0      2.0        168.0        0             0
# 3620    3.0      1750.0   3.0      3.0          0.0        0             0
# 10650   3.0      1732.0   3.0      1.0        351.0        0             0
# 12509   3.0      1893.0   3.0      2.0         18.0        0             0
# 1688    2.0      1150.0   2.0      2.0          0.0        0             0
# ...     ...         ...   ...      ...          ...      ...           ...
# 12533   2.0      1065.0   2.0      1.0          0.0        0             0
# 5465    2.0      1175.0   2.0      1.0        137.0        0             0
# 5675    2.0       970.0   2.0      1.0          0.0        0             0
# 903     3.0      1904.0   3.0      2.0          0.0        0             0
# 7647    3.0      1893.0   3.0      2.0          0.0        0             0
#
#         Bhoganhalli   Devarabeesana Halli   Devarachikkanahalli  ...  \
# 6733              0                     0                     0  ...
# 3620              0                     1                     0  ...
# 10650             0                     0                     0  ...
# 12509             0                     0                     0  ...
# 1688              0                     0                     0  ...
# ...             ...                   ...                   ...  ...
# 12533             0                     0                     0  ...
# 5465              0                     0                     0  ...
# 5675              0                     0                     0  ...
# 903               0                     0                     0  ...
# 7647              0                     0                     0  ...
#
#        manyata tech park  mvj engineering college  \
# 6733                   0                        0
# 3620                   0                        0
# 10650                  0                        0
# 12509                  0                        0
# 1688                   0                        0
# ...                  ...                      ...
# 12533                  0                        0
# 5465                   0                        0
# 5675                   0                        0
# 903                    0                        0
# 7647                   0                        0
#
#        near Ramanashree California resort  rr nagar  sapthagiri Layout  \
# 6733                                    0         0                  0
# 3620                                    0         0                  0
# 10650                                   0         0                  0
# 12509                                   0         0                  0
# 1688                                    0         0                  0
# ...                                   ...       ...                ...
# 12533                                   0         0                  0
# 5465                                    0         0                  0
# 5675                                    0         0                  0
# 903                                     0         0                  0
# 7647                                    0         0                  0
#
#        singapura paradise  t.c palya  tc.palya  vinayakanagar  whitefiled
# 6733                    0          0         0              0           0
# 3620                    0          0         0              0           0
# 10650                   0          0         0              0           0
# 12509                   0          0         0              0           0
# 1688                    0          0         0              0           0
# ...                   ...        ...       ...            ...         ...
# 12533                   0          0         0              0           0
# 5465                    0          0         0              0           0
# 5675                    0          0         0              0           0
# 903                     0          0         0              0           0
# 7647                    0          0         0              0           0
#
# [8897 rows x 1119 columns]

# %%
X_test = df_test[['size', 'total_sqft', 'bath', 'balcony', 'days_before']]
location_test_d = pd.get_dummies(df_test['location'])
fullX_test = pd.concat([X_test, location_test_d], axis=1)
fullX_test
# Out:
#        size  total_sqft  bath  balcony  days_before   Banaswadi  \
# 12716   3.0      1694.0   3.0      1.0          0.0           0
# 10172   2.0       940.0   2.0      1.0        107.0           0
# 3060    2.0       883.0   2.0      1.0          0.0           0
# 319     2.0      1113.0   2.0      1.0          0.0           0
# 8353    2.0      2480.0   2.0      1.0          0.0           0
# ...     ...         ...   ...      ...          ...         ...
# 10806   2.0      1200.0   2.0      1.0          0.0           0
# 4133    3.0      1600.0   2.0      2.0          0.0           0
# 3980    3.0      1329.0   2.0      2.0        107.0           0
# 9896    1.0       620.0   1.0      1.0          0.0           0
# 3073    3.0      1500.0   2.0      0.0         48.0           0
#
#         Devarabeesana Halli   Devarachikkanahalli   Electronic City  \
# 12716                     0                     0                 0
# 10172                     0                     0                 0
# 3060                      0                     0                 0
# 319                       0                     0                 0
# 8353                      0                     0                 0
# ...                     ...                   ...               ...
# 10806                     0                     0                 0
# 4133                      0                     0                 0
# 3980                      0                     0                 0
# 9896                      0                     0                 0
# 3073                      0                     0                 0
#
#         Rachenahalli  ...  basaveshwarnagar  beml layout, basaveshwara nagar  \
# 12716              0  ...                 0                                0
# 10172              0  ...                 0                                0
# 3060               0  ...                 0                                0
# 319                0  ...                 0                                0
# 8353               0  ...                 0                                0
# ...              ...  ...               ...                              ...
# 10806              0  ...                 0                                0
# 4133               0  ...                 0                                0
# 3980               0  ...                 0                                0
# 9896               0  ...                 0                                0
# 3073               0  ...                 0                                0
#
#        frazertown  kadubisnahalli  kg halli jalhalli west  pavitra paradise  \
# 12716           0               0                       0                 0
# 10172           0               0                       0                 0
# 3060            0               0                       0                 0
# 319             0               0                       0                 0
# 8353            0               0                       0                 0
# ...           ...             ...                     ...               ...
# 10806           0               0                       0                 0
# 4133            0               0                       0                 0
# 3980            0               0                       0                 0
# 9896            0               0                       0                 0
# 3073            0               0                       0                 0
#
#        poornaprajna layout  ravindra nagar, T.dasarahalli peenya  sankeswari  \
# 12716                    0                                     0           0
# 10172                    0                                     0           0
# 3060                     0                                     0           0
# 319                      0                                     0           0
# 8353                     0                                     0           0
# ...                    ...                                   ...         ...
# 10806                    0                                     0           0
# 4133                     0                                     0           0
# 3980                     0                                     0           0
# 9896                     0                                     0           0
# 3073                     0                                     0           0
#
#        sarjapura main road
# 12716                    0
# 10172                    0
# 3060                     0
# 319                      0
# 8353                     0
# ...                    ...
# 10806                    0
# 4133                     0
# 3980                     0
# 9896                     0
# 3073                     0
#
# [3814 rows x 772 columns]

# %%
# Ajouter à fullX_test les colonnes manquantes dans fullX et vice versa et les mettre à 0 pour avoir le même shape
# fullX, fullX_test = fullX.align(fullX_test, fill_value=0)

# %%
# Mettre les colonnes de fullX et fullX_test dans le même ordre
# fullX = fullX.sort_values(by=sorted(fullX.columns))
# fullX_test = fullX_test.sort_values(by=sorted(fullX_test.columns))

# %%
# La méthode align ajoute la valeur 0 à toutes les colonnes manquantes dans les deux dataframes. 
# Il remplit également de 0 toutes les valeurs manquantes dans l'un ou l'autre des dataframes.
# Il faut supprimer toutes les lignes ajoutés à fullX et fullX_test
# fullX = fullX.head(X.shape[0])
# fullX_test = fullX_test.head(X_test.shape[0])
fullX, fullX_test = fullX.align(fullX_test, join='left', axis=1, fill_value=0)

# %%
fullX
# Out:
#        size  total_sqft  bath  balcony  days_before   Anekal   Basavangudi  \
# 6733    2.0      1200.0   2.0      2.0        168.0        0             0
# 3620    3.0      1750.0   3.0      3.0          0.0        0             0
# 10650   3.0      1732.0   3.0      1.0        351.0        0             0
# 12509   3.0      1893.0   3.0      2.0         18.0        0             0
# 1688    2.0      1150.0   2.0      2.0          0.0        0             0
# ...     ...         ...   ...      ...          ...      ...           ...
# 12533   2.0      1065.0   2.0      1.0          0.0        0             0
# 5465    2.0      1175.0   2.0      1.0        137.0        0             0
# 5675    2.0       970.0   2.0      1.0          0.0        0             0
# 903     3.0      1904.0   3.0      2.0          0.0        0             0
# 7647    3.0      1893.0   3.0      2.0          0.0        0             0
#
#         Bhoganhalli   Devarabeesana Halli   Devarachikkanahalli  ...  \
# 6733              0                     0                     0  ...
# 3620              0                     1                     0  ...
# 10650             0                     0                     0  ...
# 12509             0                     0                     0  ...
# 1688              0                     0                     0  ...
# ...             ...                   ...                   ...  ...
# 12533             0                     0                     0  ...
# 5465              0                     0                     0  ...
# 5675              0                     0                     0  ...
# 903               0                     0                     0  ...
# 7647              0                     0                     0  ...
#
#        manyata tech park  mvj engineering college  \
# 6733                   0                        0
# 3620                   0                        0
# 10650                  0                        0
# 12509                  0                        0
# 1688                   0                        0
# ...                  ...                      ...
# 12533                  0                        0
# 5465                   0                        0
# 5675                   0                        0
# 903                    0                        0
# 7647                   0                        0
#
#        near Ramanashree California resort  rr nagar  sapthagiri Layout  \
# 6733                                    0         0                  0
# 3620                                    0         0                  0
# 10650                                   0         0                  0
# 12509                                   0         0                  0
# 1688                                    0         0                  0
# ...                                   ...       ...                ...
# 12533                                   0         0                  0
# 5465                                    0         0                  0
# 5675                                    0         0                  0
# 903                                     0         0                  0
# 7647                                    0         0                  0
#
#        singapura paradise  t.c palya  tc.palya  vinayakanagar  whitefiled
# 6733                    0          0         0              0           0
# 3620                    0          0         0              0           0
# 10650                   0          0         0              0           0
# 12509                   0          0         0              0           0
# 1688                    0          0         0              0           0
# ...                   ...        ...       ...            ...         ...
# 12533                   0          0         0              0           0
# 5465                    0          0         0              0           0
# 5675                    0          0         0              0           0
# 903                     0          0         0              0           0
# 7647                    0          0         0              0           0
#
# [8897 rows x 1119 columns]

# %%
fullX_test
# Out:
#        size  total_sqft  bath  balcony  days_before   Anekal   Basavangudi  \
# 12716   3.0      1694.0   3.0      1.0          0.0        0             0
# 10172   2.0       940.0   2.0      1.0        107.0        0             0
# 3060    2.0       883.0   2.0      1.0          0.0        0             0
# 319     2.0      1113.0   2.0      1.0          0.0        0             0
# 8353    2.0      2480.0   2.0      1.0          0.0        0             0
# ...     ...         ...   ...      ...          ...      ...           ...
# 10806   2.0      1200.0   2.0      1.0          0.0        0             0
# 4133    3.0      1600.0   2.0      2.0          0.0        0             0
# 3980    3.0      1329.0   2.0      2.0        107.0        0             0
# 9896    1.0       620.0   1.0      1.0          0.0        0             0
# 3073    3.0      1500.0   2.0      0.0         48.0        0             0
#
#         Bhoganhalli   Devarabeesana Halli   Devarachikkanahalli  ...  \
# 12716             0                     0                     0  ...
# 10172             0                     0                     0  ...
# 3060              0                     0                     0  ...
# 319               0                     0                     0  ...
# 8353              0                     0                     0  ...
# ...             ...                   ...                   ...  ...
# 10806             0                     0                     0  ...
# 4133              0                     0                     0  ...
# 3980              0                     0                     0  ...
# 9896              0                     0                     0  ...
# 3073              0                     0                     0  ...
#
#        manyata tech park  mvj engineering college  \
# 12716                  0                        0
# 10172                  0                        0
# 3060                   0                        0
# 319                    0                        0
# 8353                   0                        0
# ...                  ...                      ...
# 10806                  0                        0
# 4133                   0                        0
# 3980                   0                        0
# 9896                   0                        0
# 3073                   0                        0
#
#        near Ramanashree California resort  rr nagar  sapthagiri Layout  \
# 12716                                   0         0                  0
# 10172                                   0         0                  0
# 3060                                    0         0                  0
# 319                                     0         0                  0
# 8353                                    0         0                  0
# ...                                   ...       ...                ...
# 10806                                   0         0                  0
# 4133                                    0         0                  0
# 3980                                    0         0                  0
# 9896                                    0         0                  0
# 3073                                    0         0                  0
#
#        singapura paradise  t.c palya  tc.palya  vinayakanagar  whitefiled
# 12716                   0          0         0              0           0
# 10172                   0          0         0              0           0
# 3060                    0          0         0              0           0
# 319                     0          0         0              0           0
# 8353                    0          0         0              0           0
# ...                   ...        ...       ...            ...         ...
# 10806                   0          0         0              0           0
# 4133                    0          0         0              0           0
# 3980                    0          0         0              0           0
# 9896                    0          0         0              0           0
# 3073                    0          0         0              0           0
#
# [3814 rows x 1119 columns]

# %%
model = LinearRegression(fit_intercept=True)
model_result = model.fit(fullX, Y)
model_result
# Out:
# LinearRegression()

# %%
y_mlr_location_pred_test = model.predict(fullX_test)

# %%
predictions = df_test.copy()
predictions['price_mlr_pred'] = y_mlr_location_pred_test

modele_location_predictions = predictions[['size', 'total_sqft', 'bath', 'balcony', 'days_before', 'location', 'price', 'price_mlr_pred']]
modele_location_predictions
# Out:
#        size  total_sqft  bath  balcony  days_before                  location  \
# 12716   3.0      1694.0   3.0      1.0          0.0               Thanisandra
# 10172   2.0       940.0   2.0      1.0        107.0                Kudlu Gate
# 3060    2.0       883.0   2.0      1.0          0.0                 Kambipura
# 319     2.0      1113.0   2.0      1.0          0.0            Motappa Layout
# 8353    2.0      2480.0   2.0      1.0          0.0    Kengeri Satellite Town
# ...     ...         ...   ...      ...          ...                       ...
# 10806   2.0      1200.0   2.0      1.0          0.0               Frazer Town
# 4133    3.0      1600.0   2.0      2.0          0.0                HSR Layout
# 3980    3.0      1329.0   2.0      2.0        107.0  Electronic City Phase II
# 9896    1.0       620.0   1.0      1.0          0.0              Malleshwaram
# 3073    3.0      1500.0   2.0      0.0         48.0                 T c palya
#
#         price  price_mlr_pred
# 12716  125.00    1.070771e+02
# 10172   69.57    3.425268e+01
# 3060    45.00    3.922093e+01
# 319     51.00    4.736108e+01
# 8353   160.00    1.191996e+02
# ...       ...             ...
# 10806   78.00    1.708520e+02
# 4133   115.00    9.297215e+01
# 3980    41.00    5.486506e+01
# 9896    86.80    2.135065e+02
# 3073    85.00   -2.465752e+09
#
# [3814 rows x 8 columns]

# %% [markdown]
# ### Diagnostics

# %%
# Histogram of residuals
residuals = df_test['price'] - modele_location_predictions['price_mlr_pred']
sb.histplot(residuals)
plt.xlabel('Residual value')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 df.to_sql('data_cleaned', engine)
#
# File c:\Users\mateo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File c:\Users\mateo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File c:\Users\mateo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File c:\Users\mateo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File c:\Users\mateo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\sql.py:829, in SQLTable.create(self)
#     827 if self.exists():
#     828     if self.if_exists == "fail":
# --> 829         raise ValueError(f"Table '{self.name}' already exists.")
#     830     elif self.if_exists == "replace":
#     831         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'data_cleaned' already exists.

# %%
mu, std = stats.norm.fit(residuals)
mu, std

# %%
fig, ax = plt.subplots()
# plot the residuals
sb.histplot(x=residuals, ax=ax, stat="density", linewidth=0, kde=True)
ax.set(title="Distribution of residuals", xlabel="residual")

# plot corresponding normal curve
xmin, xmax = plt.xlim() # the maximum x values from the histogram above
x = np.linspace(xmin, xmax, 100) # generate some x values
p = stats.norm.pdf(x, mu, std) # calculate the y values for the normal curve
sb.lineplot(x=x, y=p, color="orange", ax=ax)
plt.show()

# %% [markdown]
# **Commentaire** : Une comparaison entre notre distribution des résidus et celle de normale qu'on aurait pu avoir (dans le meilleur cas), montre que le modèle n'est pas adapté à notre ensemble de donnée. La raison se trouvant probablement sur le choix de la variable catégorielle **location** si on compare avec le modèle précédent avec la variable **area_type**

# %%
# Boxplot of residuals
sb.boxplot(x=residuals, showmeans=True);

# %% [markdown]
# **Commentaire** :On n'a pas une distribution raisonnable avec une moyenne proche de la médiane cette fois. On voit aussi beaucoup de points sortir du scope de la boite à moustache.

# %%
# Fit plot
Y_max = df_test['price'].max()
Y_min = df_test['price'].min()

ax = sb.scatterplot(x=df_test['price'], y=modele_location_predictions['price_mlr_pred'])
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Observed value of Price")
ax.set_ylabel("Predicted value of Price")

X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()

# %% [markdown]
# **Commentaire** : On voit presque tous les points en dessous de la première diagonale, notre modèle a clairement tendance à sous estimer notre variable cible. De plus, les points dans leur ensemble s'éloigne de la première diagonale, le modèle ci n'est pas adapté à notre dataset.

# %%
plt.plot(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.plot(sorted(df_test.index), modele_location_predictions['price_mlr_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %%
plt.scatter(sorted(df_test.index), df_test['price'], color='red', linewidth=1)
plt.scatter(sorted(df_test.index), modele_location_predictions['price_mlr_pred'], color='blue', linewidth=1)
plt.xlabel('Dataframe index')
plt.ylabel('Price value')
plt.show()

# %%
fullX_test['size']

# %%
modele_location_predictions['price_mlr_pred'].max()

# %% [markdown]
# **Commentaire** : En rouge, on a un aperçu des prix observés et en bleu, on a un aperçu des prix prévus par le modèle. On voit clairement dans ce graphique que notre modèle n'arrive pas à bien prévoir le prix avec les variables indépendantes : size, total_sqft, bath, balcony, days_before et **location**.

# %% [markdown]
# **Commentaire** : Avec une variable catégorielle comme **location** (+1000 catégories), on se retrouve avec un modèle très peu performant. On peut imaginer que ça ne sera pas nécesssairement mieux avec la variable catégorielle **society** (+2000 catégories)
